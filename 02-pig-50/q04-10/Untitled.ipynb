# %%
# !rm -rf input output
# !mkdir output
# %load_ext bigdata
# %pig_start
# %timeout 300
# !hadoop fs -rm truck_event_text_partition.csv
# !hadoop fs -put truck_event_text_partition.csv
# !hadoop fs -ls output/*
# !hadoop fs -rm output/*
# !hadoop fs -rmdir output
# Out:
# The bigdata extension is already loaded. To reload it, use:
#   %reload_ext bigdata
# Deleted truck_event_text_partition.csv
# -rw-r--r--   1 root supergroup          0 2020-01-28 04:06 output/_SUCCESS
# -rw-r--r--   1 root supergroup        180 2020-01-28 04:06 output/part-r-00000
# Deleted output/_SUCCESS
# Deleted output/part-r-00000

# %%
# %%pig
# alldata = LOAD 'truck_event_text_partition.csv' USING PigStorage(',')
#    AS (driverId:INT,truckId:INT,eventTime:CHARARRAY,eventType:CHARARRAY,longitude:INT,latitude:INT,eventKey:CHARARRAY,correlationId:CHARARRAY,driverName:CHARARRAY,routeId:INT,routeName:CHARARRAY,eventDate:CHARARRAY);
# data = LIMIT alldata 10;
# DUMP data;
# Out:
#  alldata = LOAD 'truck_event_text_partition.csv' USING PigStorage(',')
# ARRAY,routeId:INT,routeName:CHARARRAY,eventDate:CHARARRAY);ARRAY,driverName:CHAR
#  data = LIMIT alldata 10;
#  DUMP data;
# 2020-01-28 04:07:12,481 [main] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2020-01-28 04:07:12,481 [main] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-01-28 04:07:12,572 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-01-28 04:07:12,706 [main] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt__0001_m_000001_1' to hdfs://0.0.0.0:9000/tmp/temp-1196479147/tmp-1265931421/_temporary/0/task__0001_m_000001
# ...

# %%
# %%pig
# numero= ORDER data BY $0,$1,$2;
# DUMP numero
# Out:
#  numero= ORDER data BY $0,$1,$2;
#  DUMP numero
# 2020-01-28 04:07:24,101 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-28 04:07:24,239 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2020-01-28 04:07:24,242 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.output.compress is deprecated. Instead, use mapreduce.output.fileoutputformat.compress
# 2020-01-28 04:07:24,243 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2020-01-28 04:07:24,249 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.submit.replication is deprecated. Instead, use mapreduce.client.submit.file.replication
# ...

# %%
# %%pig
# top = FOREACH numero GENERATE $0,$1,$2;
# DUMP top;
# Out:
#  top = FOREACH numero GENERATE $0,$1,$2;
#  DUMP top;
# 2020-01-28 04:10:36,977 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-28 04:10:37,913 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-28 04:10:37,926 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-01-28 04:10:37,939 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-01-28 04:10:37,975 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-01-28 04:10:37,997 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1580178810336_0052
# ...

# %%
# %%pig
# STORE top INTO 'output' USING PigStorage(',');
# fs -get output/ .
# Out:
#  STORE top INTO 'output' USING PigStorage(',');
# 2020-01-28 04:13:08,447 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2020-01-28 04:13:08,496 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-28 04:13:08,995 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-28 04:13:09,004 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-01-28 04:13:09,010 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-01-28 04:13:09,440 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# ...

# %%
# %pig_quit
