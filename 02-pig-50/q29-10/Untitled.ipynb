# %%
# !rm -rf input output
# !mkdir output
# %load_ext bigdata
# %pig_start
# %timeout 300
# !hadoop fs -rm data.csv
# !hadoop fs -put data.csv
# !hadoop fs -ls output/*
# !hadoop fs -rm output/*
# !hadoop fs -rmdir output
# Out:
# The bigdata extension is already loaded. To reload it, use:
#   %reload_ext bigdata
# Deleted data.csv
# -rw-r--r--   1 root supergroup          0 2020-01-22 04:49 output/_SUCCESS
# -rw-r--r--   1 root supergroup        648 2020-01-22 04:49 output/part-m-00000
# Deleted output/_SUCCESS
# Deleted output/part-m-00000

# %%
# %%pig
# data = LOAD 'data.csv' USING PigStorage(',')
#    AS (f1:INT, f2:CHARARRAY, f3:CHARARRAY, f4:CHARARRAY, f5:CHARARRAY, f6:INT);
# DUMP data;
# Out:
#  data = LOAD 'data.csv' USING PigStorage(',')
# ); AS (f1:INT, f2:CHARARRAY, f3:CHARARRAY, f4:CHARARRAY, f5:CHARARRAY, f6:INT
#  DUMP data;
# 2020-01-22 04:51:56,574 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-22 04:51:56,725 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2020-01-22 04:51:56,728 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.output.compress is deprecated. Instead, use mapreduce.output.fileoutputformat.compress
# 2020-01-22 04:51:56,737 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.submit.replication is deprecated. Instead, use mapreduce.client.submit.file.replication
# ...

# %%
# %%pig
# y = FOREACH data GENERATE f4,ToDate(f4,'yyyy-MM-dd') AS fecha;
# DUMP y;
# Out:
#  y = FOREACH data GENERATE f4,ToDate(f4,'yyyy-MM-dd') AS fecha;
#  DUMP y;
# 2020-01-22 04:52:14,122 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-22 04:52:14,662 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-22 04:52:14,686 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-01-22 04:52:14,713 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-01-22 04:52:14,740 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-01-22 04:52:14,780 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1579666620006_0014
# ...

# %%
# %%pig
# b = FOREACH y GENERATE f4, fecha, GetMonth(fecha) AS mes, ToString(fecha, 'MM') AS mes_2_dig;
# DUMP b;
# Out:
#  'MM') AS mes_2_dig;ATE f4, fecha, GetMonth(fecha) AS mes, ToString(fecha,
#  DUMP b;
# 2020-01-22 04:52:31,154 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-22 04:52:32,122 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-22 04:52:32,137 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-01-22 04:52:32,149 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-01-22 04:52:32,184 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-01-22 04:52:32,217 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1579666620006_0015
# ...

# %%
# %%pig
# c = FOREACH b GENERATE f4,fecha, mes, mes_2_dig, (
# case mes
# when 1 then 'ene'
# when 2 then 'feb'
# when 3 then 'mar'
# when 4 then 'abr'
# when 5 then 'may'
# when 6 then 'jun'
# when 7 then 'jul'
# when 8 then 'ago'
# when 9 then 'sep'
# when 10 then 'oct'
# when 11 then 'nov'
# else 'dic' END
# ) AS nombre_mes;
# DUMP c;
# Out:
#  c = FOREACH b GENERATE f4,fecha, mes, mes_2_dig, (
# case mes
# when 1 then 'ene'
# when 2 then 'feb'
# when 3 then 'mar'
# when 4 then 'abr'
# when 5 then 'may'
# when 6 then 'jun'
# when 7 then 'jul'
# when 8 then 'ago'
# when 9 then 'sep'
# when 10 then 'oct'
# when 11 then 'nov'
# else 'dic' END
# ) AS nombre_mes;
#  DUMP c;
# 2020-01-22 04:52:49,420 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-22 04:52:49,963 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-22 04:52:49,988 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-01-22 04:52:49,998 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# ...

# %%
# %%pig
# d = FOREACH c GENERATE f4, nombre_mes, mes_2_dig, mes;
# DUMP d;
# Out:
#  d = FOREACH c GENERATE f4, nombre_mes, mes_2_dig, mes;
#  DUMP d;
# 2020-01-22 04:53:06,161 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-22 04:53:07,089 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-22 04:53:07,098 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-01-22 04:53:07,116 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-01-22 04:53:07,560 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-01-22 04:53:07,596 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1579666620006_0017
# ...

# %%
# %%pig
# STORE d INTO 'output'USING PigStorage(',');
# fs -get output/ .
# Out:
#  STORE d INTO 'output'USING PigStorage(',');
# 2020-01-22 04:53:23,487 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2020-01-22 04:53:23,568 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-22 04:53:24,078 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-01-22 04:53:24,087 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-01-22 04:53:24,096 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-01-22 04:53:24,535 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# ...

# %%
# %pig_quit
